# %%
from sklearn.linear_model import LinearRegression

# %%
import numpy as np

# %%
X = np.array([[1, 1], [1, 2], [2, 2], [2, 3]])

# %%
y = np.dot(X, np.array([1, 2])) + 3

# %%
reg = LinearRegression()

# %%
reg.get_params()
# Out:
# {'copy_X': True,
#  'fit_intercept': True,
#  'n_jobs': None,
#  'normalize': False,
#  'positive': False}

# %%
reg = LinearRegression().fit(X, y)

# %%
reg.get_params(deep=True)
# Out:
# {'copy_X': True,
#  'fit_intercept': True,
#  'n_jobs': None,
#  'normalize': False,
#  'positive': False}

# %%
from sklift.datasets import fetch_lenta

# %%
data = fetch_lenta()

# %%
data.keys()
# Out:
# dict_keys(['data', 'target', 'treatment', 'DESCR', 'feature_names', 'target_name', 'treatment_name'])

# %%
df = data['data']

# %%
data['target'].value_counts()
# Out:
# 0    612661
# 1     74368
# Name: response_att, dtype: int64

# %%
df.loc[:, 'target'] = data['target']

# %%
data['treatment'].value_counts()
# Out:
# test       515892
# control    171137
# Name: group, dtype: int64

# %%
df.loc[:, 'treatment'] = data['treatment']

# %%
data['treatment_name']
# Out:
# 'group'

# %%
df
# Out:
#          age  cheque_count_12m_g20  cheque_count_12m_g21  \
# 0       47.0                   3.0                  22.0
# 1       57.0                   1.0                   0.0
# 2       38.0                   7.0                   0.0
# 3       65.0                   6.0                   3.0
# 4       61.0                   0.0                   1.0
# ...      ...                   ...                   ...
# 687024  35.0                   0.0                   0.0
# 687025  33.0                   0.0                   0.0
# 687026  36.0                   0.0                   0.0
# 687027  37.0                   0.0                   1.0
# 687028  40.0                   0.0                   1.0
#
#         cheque_count_12m_g25  cheque_count_12m_g32  cheque_count_12m_g33  \
# 0                       19.0                   3.0                  28.0
# 1                        2.0                   1.0                   1.0
# ...

# %%
df.to_pickle('./test_data.pkl')

# %%
import pandas as pd

# %%
pd.read_pickle('test_data.pkl')
# Out:
#          age  cheque_count_12m_g20  cheque_count_12m_g21  \
# 0       47.0                   3.0                  22.0
# 1       57.0                   1.0                   0.0
# 2       38.0                   7.0                   0.0
# 3       65.0                   6.0                   3.0
# 4       61.0                   0.0                   1.0
# ...      ...                   ...                   ...
# 687024  35.0                   0.0                   0.0
# 687025  33.0                   0.0                   0.0
# 687026  36.0                   0.0                   0.0
# 687027  37.0                   0.0                   1.0
# 687028  40.0                   0.0                   1.0
#
#         cheque_count_12m_g25  cheque_count_12m_g32  cheque_count_12m_g33  \
# 0                       19.0                   3.0                  28.0
# 1                        2.0                   1.0                   1.0
# ...

# %%
import pickle

# %%
import pandas as pd

# %%
data = pd.read_pickle("./test_data.pkl")

# %%
data
# Out:
#          age  cheque_count_12m_g20  cheque_count_12m_g21  \
# 0       47.0                   3.0                  22.0
# 1       57.0                   1.0                   0.0
# 2       38.0                   7.0                   0.0
# 3       65.0                   6.0                   3.0
# 4       61.0                   0.0                   1.0
# ...      ...                   ...                   ...
# 687024  35.0                   0.0                   0.0
# 687025  33.0                   0.0                   0.0
# 687026  36.0                   0.0                   0.0
# 687027  37.0                   0.0                   1.0
# 687028  40.0                   0.0                   1.0
#
#         cheque_count_12m_g25  cheque_count_12m_g32  cheque_count_12m_g33  \
# 0                       19.0                   3.0                  28.0
# 1                        2.0                   1.0                   1.0
# ...

# %%
from sklearn.base import BaseEstimator

# %%
def BaseUpliftEstimator(BaseEstimator):
    def __init__(self):
        pass
    def compute_ate(self):
        pass

# %%
def SLearner(BaseUpliftEstimator):
    def __init__(
        self,
        model_class,
        treatment_col=None,
        target_col=None,
    ):
        self.model_class = model_class
        self.model_args = model_args
        self.treatment_col = treatment_col
        self.target_col = target_col
    
    def fit(
        self, 
        
    ):
        pass
